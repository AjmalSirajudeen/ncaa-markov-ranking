# %% [markdown]
# # NCAA LRMC analysis
#
# Modern Python reimplementation of a Cornell graduate LRMC basketball ranking project.
#
# Run `python scripts/run_pipeline.py` for the full batch pipeline. This notebook mirrors the main steps.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.data_loader import load_games
from src.rankings import build_rankings, evaluate_games, accuracy_summary, save_figures

games = load_games()
result = build_rankings(games)
print(result["ranking"].head(10))
print(accuracy_summary(evaluate_games(games, result["pi"])))
save_figures(games, result, ROOT / "outputs" / "figures")
